# %%
iris = load_iris()
X = iris.data 

df = pd.DataFrame(X,columns = iris.feature_names)
df["Species"] = iris.target_names[iris.target]

df.head()

# %%
class MyPCA

    def __init(self):
        self.xBar = None
        self.V = None
        self.Lamda = None
        self.Cp = None
        self.Fp = None
        return

    def fit
